# %%
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, Dropout, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
import os
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
train_filter = ImageDataGenerator(rescale = 1./255, rotation_range = 10, width_shift_range = 0.1, 
                                  height_shift_range = 0.1, zoom_range = 0.2, horizontal_flip = True)

test_filter = ImageDataGenerator(rescale = 1./255)

# %%
# batch size
n_batch = 32

# load the datasets
train_dataset = train_filter.flow_from_directory('./image/training_set', target_size = (300, 300), color_mode = 'grayscale', 
                                                batch_size = n_batch, classes = ['ROCK', 'PAPER', 'SCISSOR','NONE'],
                                                class_mode = 'categorical')

test_dataset = test_filter.flow_from_directory('./image/testing_set', target_size = (300, 300), color_mode = 'grayscale', 
                                                batch_size = n_batch, classes = ['ROCK', 'PAPER', 'SCISSOR','NONE'],
                                                class_mode = 'categorical')
# Out:
# Found 3297 images belonging to 4 classes.
# Found 1932 images belonging to 4 classes.

# %%
# set up the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation = 'relu', input_shape = (300, 300, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation = 'relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation = 'relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(4, activation = 'sigmoid'))

model.summary()

# set up the optimizer
model.compile('adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

callbacks_list = [
    EarlyStopping(monitor='val_loss', patience=10),
    ModelCheckpoint(filepath='model.h5', monitor='val_loss', save_best_only=True),
]


history = model.fit_generator(
    train_dataset,
    steps_per_epoch=71,
    epochs=10,
    validation_data=test_dataset,
    validation_steps=28,
    callbacks=callbacks_list
)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 298, 298, 32)      320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 149, 149, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 147, 147, 64)      18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 73, 73, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 71, 71, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 35, 35, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 33, 33, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               16777728
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 17,020,036
# Trainable params: 17,020,036
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 71/71 [==============================] - 28s 390ms/step - loss: 1.0727 - acc: 0.4753 - val_loss: 1.1461 - val_acc: 0.6289
# Epoch 2/10
# 71/71 [==============================] - 20s 279ms/step - loss: 0.8393 - acc: 0.6158 - val_loss: 0.8270 - val_acc: 0.6775
# Epoch 3/10
# 71/71 [==============================] - 20s 276ms/step - loss: 0.5212 - acc: 0.7997 - val_loss: 0.6753 - val_acc: 0.7293
# Epoch 4/10
# 71/71 [==============================] - 20s 279ms/step - loss: 0.3102 - acc: 0.8816 - val_loss: 0.6565 - val_acc: 0.7785
# Epoch 5/10
# 71/71 [==============================] - 20s 276ms/step - loss: 0.2422 - acc: 0.9137 - val_loss: 0.4719 - val_acc: 0.8520
# Epoch 6/10
# 71/71 [==============================] - 20s 276ms/step - loss: 0.1609 - acc: 0.9467 - val_loss: 0.4654 - val_acc: 0.8654
# Epoch 7/10
# 71/71 [==============================] - 20s 276ms/step - loss: 0.1543 - acc: 0.9441 - val_loss: 0.3710 - val_acc: 0.8742
# Epoch 8/10
# 71/71 [==============================] - 20s 279ms/step - loss: 0.1113 - acc: 0.9617 - val_loss: 0.4506 - val_acc: 0.8675
# Epoch 9/10
# 71/71 [==============================] - 20s 276ms/step - loss: 0.1121 - acc: 0.9595 - val_loss: 0.5767 - val_acc: 0.8504
# Epoch 10/10
# 70/71 [============================>.] - ETA: 0s - loss: 0.0876 - acc: 0.9701

# %%
plt.figure(figsize = (16, 6))

# 1st plot
plt.subplot(1, 2, 1)
num_epochs = len(history.history['loss'])
plt.plot(range(num_epochs), history.history['loss'], 'r', label = "train")
plt.plot(range(num_epochs), history.history['val_loss'], 'b', label = "test")
plt.legend(prop = {'size' : 15})
plt.ylabel("loss")
plt.xlabel("num_iterations")

# 2nd plot
plt.subplot(1, 2, 2)
num_epochs = len(history.history['loss'])
plt.plot(range(num_epochs), history.history['acc'], 'r', label = "train")
plt.plot(range(num_epochs), history.history['val_acc'], 'b', label = "test")
plt.legend(prop = {'size' : 15})
plt.ylabel("accuracy")
plt.xlabel("num_iterations")
# Out:
# Text(0.5,0,'num_iterations')
